# %% [markdown]
# # Supplemental Tables

# %%
# Load packages.
import numpy as np
import pandas as pd
# Print version numbers.
print('numpy', np.__version__)
print('pandas', pd.__version__)
# Out:
# numpy 1.22.3
# pandas 1.4.2

# %%
# Intialize the pandas preferences.
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Table S1

# %%
# Load the dataframe.
df = pd.read_csv('./dataframes/mxl_pbs_den_specific_sites_72kb.csv')
df.to_csv('./supp_tables/S1.csv', index=False)

# %% [markdown]
# Population Branch Statistic (PBS) values for the 149 Denisovan-specific SNPs within the focal 72kb \textit{MUC19} region for all 64 MXL individuals (significance threshold = 0.141), 29 MXL individuals (significance threshold = 0.246) with 50\% or more genome-wide Indigenous American ancestry, and 35 MXL individuals (significance threshold = 0.11) with less than 50\% genome-wide Indigenous American ancestry. Note that for all configurations CHB and CEU were used as control populations and that positions 40791702 and 40820354 are undefined as it is not a segregating site amongst the MXL, CHB, and CEU populations.

# %%
df
# Out:
#      Position  All MXL Inds.  Indigenous American Anc. Inds.  \
# 0    40788647       0.279487                        0.405784
# 1    40789962       0.279487                        0.405784
# 2    40790924       0.279487                        0.405784
# 3    40791702            NaN                             NaN
# 4    40791852       0.279487                        0.405784
# 5    40792197       0.279487                        0.405784
# 6    40792300       0.279487                        0.405784
# 7    40792703       0.279487                        0.405784
# 8    40792856       0.279487                        0.405784
# 9    40793515       0.279487                        0.405784
# 10   40793899       0.279487                        0.405784
# 11   40794293       0.279487                        0.405784
# 12   40794452       0.279487                        0.405784
# 13   40796334       0.279487                        0.405784
# ...

# %% [markdown]
# ## Table S2

# %%
# Load the dataframe.
df = pd.read_csv('./dataframes/tgp_arc_der_freq_den_specific_sites_72kb.csv')
df.to_csv('./supp_tables/S2.csv', index=False)

# %% [markdown]
# Derived allele frequencies for the 149 Denisovan-specific SNPs within the focal 72kb \textit{MUC19} region for the sequenced Denisovan (DEN), Altai Neanderthal (ALT), Chagyrskaya Neanderthal (CHA), Vindija Neanderthal (VIN), and all TGP populations.

# %%
df
# Out:
#      Position  DEN  ALT  CHA  VIN       LWK       GWD       MSL       ESN  \
# 0    40788647  0.0  1.0  0.5  0.5  1.000000  1.000000  1.000000  1.000000
# 1    40789962  1.0  0.0  0.5  0.5  0.000000  0.008850  0.000000  0.000000
# 2    40790924  0.0  1.0  0.5  0.5  1.000000  1.000000  1.000000  1.000000
# 3    40791702  1.0  0.0  0.0  0.0  0.000000  0.000000  0.000000  0.000000
# 4    40791852  0.0  1.0  0.5  0.5  1.000000  1.000000  1.000000  1.000000
# 5    40792197  0.0  1.0  0.5  0.5  1.000000  1.000000  1.000000  1.000000
# 6    40792300  0.0  1.0  0.5  0.5  1.000000  1.000000  1.000000  1.000000
# 7    40792703  0.0  1.0  0.5  0.5  1.000000  1.000000  1.000000  1.000000
# 8    40792856  1.0  0.0  0.5  0.5  0.000000  0.000000  0.000000  0.000000
# 9    40793515  1.0  0.0  0.5  0.5  0.000000  0.000000  0.005882  0.000000
# 10   40793899  1.0  0.0  0.5  0.5  0.000000  0.000000  0.000000  0.000000
# 11   40794293  0.0  1.0  0.5  0.5  1.000000  1.000000  1.000000  1.000000
# ...

# %% [markdown]
# ## Table S3

# %%
# Load the dataframe.
df = pd.read_csv('./dataframes/tgp_arc_hap_seq_div_summary_72kb.csv')
df.to_csv('./supp_tables/S3.csv', index=False)

# %% [markdown]
# Sequence divergence at the focal 72kb \textit{MUC19} region between all chromosomes in the TGP and the sequenced Denisovan (DEN), Altai Neanderthal (ALT), Chagyrskaya Neanderthal (CHA), Vindija Neanderthal (VIN) diplotypes.

# %%
df
# Out:
#        Sample Population Super Population  Chr. 1 (DEN)  Chr. 2 (DEN)  \
# 0     HG00096        GBR              EUR      0.004372      0.004392
# 1     HG00097        GBR              EUR      0.004411      0.004566
# 2     HG00099        GBR              EUR      0.004334      0.003753
# 3     HG00100        GBR              EUR      0.004450      0.004353
# 4     HG00101        GBR              EUR      0.004353      0.004469
# 5     HG00102        GBR              EUR      0.004469      0.004314
# 6     HG00103        GBR              EUR      0.001045      0.004372
# 7     HG00105        GBR              EUR      0.004314      0.004392
# 8     HG00106        GBR              EUR      0.004314      0.004334
# 9     HG00107        GBR              EUR      0.004334      0.003889
# 10    HG00108        GBR              EUR      0.004450      0.003850
# 11    HG00109        GBR              EUR      0.004392      0.004372
# ...

# %% [markdown]
# ## Table S4

# %%
# Load the dataframe.
df = pd.read_csv('./dataframes/tgp_archaic_snp_denisty_72kb.csv')
df = df[df['Archaic'] == 'Denisovan']
# Convert the dataframe to a numpy matrix.
mat = df.to_numpy()[:, [1, 2, 5]]
# Intialize the columns.
cols = [
    'SNP Type', r'{\textit{MUC19} \\ SNP Denisty}', r'\textit{P-value}',
]
# Intialize a table header.
header = r'''\begin{longtblr}
{
colspec={XXX},
columns={halign=c},
width=\linewidth,
rowhead=1,
row{even}={gray9},
row{1}={brown9},
caption={Table S4: Denisovan-specific SNP density for the focal 72kb \textit{MUC19} region. The \textit{P-value} represents the proportion of non-overlapping 72kb windows of comparable effective sequence length with a Denisovan-specific SNP density greater than or equal to what is observed at the 72kb \textit{MUC19} region. After accounting for two multiple-comparisons using the Bonferroni correction, a \textit{P-value} less than 0.025 is considered significant.},
}'''+'\n'\
+ r'\hline'+'\n'\
+ r' & '.join(f'{col}' for col in cols)+r' \\'+'\n'\
+ r'\hline'+'\n'\
# Open the table.
table = open('./supp_tables/tgp_den_snp_denisty_72kb.tex', 'w')
# Write the header.
table.write(header)
# For every row...
for i in range(mat.shape[0]):
    # Write the results.
    table.write(
        r'{0} & {1} & {2}'.format(mat[i, 0], round(mat[i, 1]), r'$<3.242e^{-5}$')\
        + r' \\'+'\n'+r'\hline'+'\n'
        )
# Write the footer.
table.write(r'\end{longtblr}'+'\n')
# Close the table file.
table.close()

# %% [markdown]
# Table S4: Denisovan-specific SNP density for the focal 72kb \textit{MUC19} region. The \textit{P-value} represents the proportion of non-overlapping 72kb windows of comparable effective sequence length with a Denisovan-specific SNP density greater than or equal to what is observed at the 72kb \textit{MUC19} region. After accounting for two multiple-comparisons using the Bonferroni correction, a \textit{P-value} less than 0.025 is considered significant.

# %%
df.iloc[:, [1, 2, 5]]
# Out:
#     SNP Type  $MUC19$ (Archaic SNP Denisty)   $P-value$
# 0    Derived                             84  <3.242e-05
# 1  Ancestral                             65  <3.242e-05

# %% [markdown]
# ## Table S5

# %%
# Load the dataframe.
df = pd.read_csv('./dataframes/tgp_archaic_snp_denisty_72kb.csv')
df = df[df['Archaic'] != 'Denisovan']
# Convert the dataframe to a numpy matrix.
mat = df.to_numpy()[:, [1, 2, 5]]
# Intialize the columns.
cols = [
    'SNP Type', r'{\textit{MUC19} \\ SNP Denisty}', r'\textit{P-value}',
]
# Intialize a table header.
header = r'''\begin{longtblr}
{
colspec={XXX},
columns={halign=c},
width=\linewidth,
rowhead=1,
row{even}={gray9},
row{1}={brown9},
caption={Table S5: Neanderthal-specific SNP density for the focal 72kb \textit{MUC19} region. The \textit{P-value} represents the proportion of non-overlapping 72kb windows of comparable effective sequence length with a Neanderthal-specific SNP density greater than or equal to what is observed at the 72kb \textit{MUC19} region. After accounting for two multiple-comparisons using the Bonferroni correction, a \textit{P-value} less than 0.025 is considered significant.},
}'''+'\n'\
+ r'\hline'+'\n'\
+ r' & '.join(f'{col}' for col in cols)+r' \\'+'\n'\
+ r'\hline'+'\n'\
# Open the table.
table = open('./supp_tables/tgp_nea_snp_denisty_72kb.tex', 'w')
# Write the header.
table.write(header)
# Write the first row results.
table.write(
    r'{0} & {1} & {2}'.format(mat[0, 0], round(mat[0, 1]), round(float(mat[0, 2]), 5))\
    + r' \\'+'\n'+r'\hline'+'\n'
)
# Write the second row results.
table.write(
    r'{0} & {1} & {2}'.format(mat[1, 0], round(mat[1, 1]), r'$>0.999968$')\
    + r' \\'+'\n'+r'\hline'+'\n'
)
# Write the footer.
table.write(r'\end{longtblr}'+'\n')
# Close the table file.
table.close()

# %% [markdown]
# Table S5: Neanderthal-specific SNP density for the focal 72kb \textit{MUC19} region. The \textit{P-value} represents the proportion of non-overlapping 72kb windows of comparable effective sequence length with a Neanderthal-specific SNP density greater than or equal to what is observed at the 72kb \textit{MUC19} region. After accounting for two multiple-comparisons using the Bonferroni correction, a \textit{P-value} less than 0.025 is considered significant.

# %%
df.iloc[:, [1, 2, 5]]
# Out:
#     SNP Type  $MUC19$ (Archaic SNP Denisty)          $P-value$
# 2    Derived                              5  0.590332933510552
# 3  Ancestral                              0          >0.999968

# %% [markdown]
# ## Table S6

# %%
# Load the dataframe.
df = pd.read_csv('./dataframes/p1_yri_p2_ooa_p3_den_72kb.csv')
# Convert the dataframe to a numpy matrix.
mat = df.to_numpy()[:, [0, 1, 2, 3, 4, 5, 6, 9, 12]]
# Intialize the columns.
cols = [
    'P1', 'P2', 'P3',
    r'\textit{ABBA}', r'\textit{BABA}', r'\textit{BAAA}', r'\textit{ABAA}',
    r'\textit{D+}', r'\textit{P-value}',
]
# Intialize a table header.
header = r'''\begin{longtblr}
{
colspec={XXXXXXXXX},
columns={halign=c},
width=\linewidth,
rowhead=1,
row{even}={gray9},
row{1}={brown9},
caption={Table S6: \textit{D+} results for the focal 72kb \textit{MUC19} region where the Yoruba in Ibadan, Nigeria population (YRI) is P1, every non-African population as P2, and the sequenced Denisovan (DEN) as P3, where ancestral states were polarized using the ancestral allele calls inferred from a six primate alignment using the EPO pipeline. The \textit{P-value} represents if the observed \textit{D+} is significantly different than zero, where \textit{P-values} were computed by building a \textit{z}-distribution of \textit{D+} values from each non-overlapping 72kb window of comparable effective sequence length. After accounting for 19 multiple-comparisons using the Bonferroni correction, a \textit{P-value} less than 0.00263 is considered significant. A significant and positive \textit{D+} result suggests that P2 and the sequenced Denisovan share more derived and ancestral alleles than expected.},
}'''+'\n'\
+ r'\hline'+'\n'\
+ r' & '.join(f'{col}' for col in cols)+r' \\'+'\n'\
+ r'\hline'+'\n'\
# Open the table.
table = open('./supp_tables/p1_yri_p2_ooa_p3_den_72kb.tex', 'w')
# Write the header.
table.write(header)
# For every row...
for i in range(mat.shape[0]):
    # Write the results.
    table.write(
        r' & '.join(f'{mat[i, j]}' for j in range(3))+r' & '\
        + r' & '.join('{:.5f}'.format(mat[i, j]).rstrip('0').rstrip('.') for j in range(3, mat.shape[1]))\
        + r' \\'+'\n'+r'\hline'+'\n'
        )
# Write the footer.
table.write(r'\end{longtblr}'+'\n')
# Close the table file.
table.close()

# %% [markdown]
# Table S6: \textit{D+} results for the focal 72kb \textit{MUC19} region where the Yoruba in Ibadan, Nigeria population (YRI) is P1, every non-African population as P2, and the sequenced Denisovan (DEN) as P3, where ancestral states were polarized using the ancestral allele calls inferred from a six primate alignment using the EPO pipeline. The \textit{P-value} represents if the observed \textit{D+} is significantly different than zero, where \textit{P-values} were computed by building a \textit{z}-distribution of \textit{D+} values from each non-overlapping 72kb window of comparable effective sequence length. After accounting for 19 multiple-comparisons using the Bonferroni correction, a \textit{P-value} less than 0.00263 is considered significant. A significant and positive \textit{D+} result suggests that P2 and the sequenced Denisovan share more derived and ancestral alleles than expected.

# %%
df.iloc[:, [0, 1, 2, 3, 4, 5, 6, 9, 12]]
# Out:
#      P1   P2   P3       ABBA      BABA       BAAA       ABAA      $D+$  \
# 0   YRI  PEL  DEN  23.393328  4.786520  35.842157  21.650926  0.382828
# 1   YRI  MXL  DEN  30.904767  4.670247  42.234845  22.479782  0.458568
# 2   YRI  CLM  DEN   9.524749  7.114780  24.347764  23.179718  0.055761
# 3   YRI  PUR  DEN  11.099826  6.491208  25.586049  21.414218  0.135939
# 4   YRI  BEB  DEN  16.469423  6.354543  29.672508  21.686612  0.244001
# 5   YRI  STU  DEN  13.305374  6.207879  27.355074  21.026098  0.197755
# 6   YRI  ITU  DEN  12.638526  6.514070  26.593637  21.370053  0.169080
# 7   YRI  PJL  DEN   7.609785  6.933859  22.327739  21.107832  0.032698
# 8   YRI  GIH  DEN  11.594997  6.497955  25.868932  21.268563  0.148664
# 9   YRI  CHB  DEN   7.673499  4.811893  22.032048  20.516631  0.079533
# 10  YRI  KHV  DEN  12.169776  4.858750  25.908904  20.679527  0.197124
# 11  YRI  CHS  DEN   8.019709  5.061640  22.458422  20.606966  0.085660
# ...

# %% [markdown]
# ## Table S7

# %%
# Load the dataframe.
df = pd.read_csv('./dataframes/p1_yri_p2_ooa_p3_alt_72kb.csv')
# Convert the dataframe to a numpy matrix.
mat = df.to_numpy()[:, [0, 1, 2, 3, 4, 5, 6, 9, 12]]
# Intialize the columns.
cols = [
    'P1', 'P2', 'P3',
    r'\textit{ABBA}', r'\textit{BABA}', r'\textit{BAAA}', r'\textit{ABAA}',
    r'\textit{D+}', r'\textit{P-value}',
]
# Intialize a table header.
header = r'''\begin{longtblr}
{
colspec={XXXXXXXXX},
columns={halign=c},
width=\linewidth,
rowhead=1,
row{even}={gray9},
row{1}={brown9},
caption={Table S7: \textit{D+} results for the focal 72kb \textit{MUC19} region where the Yoruba in Ibadan, Nigeria population (YRI) is P1, every non-African population as P2, and the Altai Neanderthal (ALT) as P3, where ancestral states were polarized using the ancestral allele calls inferred from a six primate alignment using the EPO pipeline. The \textit{P-value} represents if the observed \textit{D+} is significantly different than zero, where \textit{P-values} were computed by building a \textit{z}-distribution of \textit{D+} values from each non-overlapping 72kb window of comparable effective sequence length. After accounting for 19 multiple-comparisons using the Bonferroni correction, a \textit{P-value} less than 0.00263 is considered significant. A significant and negative \textit{D+} result suggests that the YRI population and the Altai Neanderthal share more derived and ancestral alleles than expected.},
}'''+'\n'\
+ r'\hline'+'\n'\
+ r' & '.join(f'{col}' for col in cols)+r' \\'+'\n'\
+ r'\hline'+'\n'\
# Open the table.
table = open('./supp_tables/p1_yri_p2_ooa_p3_alt_72kb.tex', 'w')
# Write the header.
table.write(header)
# For every row...
for i in range(mat.shape[0]):
    # Write the results.
    table.write(
        r' & '.join(f'{mat[i, j]}' for j in range(3))+r' & '\
        + r' & '.join('{:.5f}'.format(mat[i, j]).rstrip('0').rstrip('.') for j in range(3, mat.shape[1]))\
        + r' \\'+'\n'+r'\hline'+'\n'
        )
# Write the footer.
table.write(r'\end{longtblr}'+'\n')
# Close the table file.
table.close()

# %% [markdown]
# Table S7: \textit{D+} results for the focal 72kb \textit{MUC19} region where the Yoruba in Ibadan, Nigeria population (YRI) is P1, every non-African population as P2, and the Altai Neanderthal (ALT) as P3, where ancestral states were polarized using the ancestral allele calls inferred from a six primate alignment using the EPO pipeline. The \textit{P-value} represents if the observed \textit{D+} is significantly different than zero, where \textit{P-values} were computed by building a \textit{z}-distribution of \textit{D+} values from each non-overlapping 72kb window of comparable effective sequence length. After accounting for 19 multiple-comparisons using the Bonferroni correction, a \textit{P-value} less than 0.00263 is considered significant. A significant and negative \textit{D+} result suggests that the YRI population and the Altai Neanderthal share more derived and ancestral alleles than expected.

# %%
df.iloc[:, [0, 1, 2, 3, 4, 5, 6, 9, 12]]
# Out:
#      P1   P2   P3      ABBA       BABA       BAAA       ABAA      $D+$  \
# 0   YRI  PEL  ALT  6.896895  20.269826  20.576498  38.147358 -0.360270
# 1   YRI  MXL  ALT  7.477286  26.050492  21.159288  45.907263 -0.430652
# 2   YRI  CLM  ALT  4.759013  12.471680  19.060013  27.945454 -0.258392
# 3   YRI  PUR  ALT  5.280649  12.760706  19.398282  27.233396 -0.236809
# 4   YRI  BEB  ALT  5.750619  16.580184  19.586402  32.405416 -0.318188
# 5   YRI  STU  ALT  5.480664  14.143791  19.531908  28.850808 -0.264414
# 6   YRI  ITU  ALT  5.365015  13.866376  19.344272  28.643564 -0.264815
# 7   YRI  PJL  ALT  4.878086  10.479938  18.833743  23.839530 -0.182792
# 8   YRI  GIH  ALT  5.304319  13.044925  19.409340  27.559241 -0.243280
# 9   YRI  CHB  ALT  6.026654   7.757551  19.120370  22.163475 -0.086693
# 10  YRI  KHV  ALT  6.367775  11.319374  19.539188  26.481528 -0.186695
# 11  YRI  CHS  ALT  5.978064   8.326345  19.231812  22.648611 -0.102609
# ...

# %% [markdown]
# ## Table S8

# %%
# Load the dataframe.
df = pd.read_csv('./dataframes/p1_yri_p2_ooa_p3_vin_72kb.csv')
# Convert the dataframe to a numpy matrix.
mat = df.to_numpy()[:, [0, 1, 2, 3, 4, 5, 6, 9, 12]]
# Intialize the columns.
cols = [
    'P1', 'P2', 'P3',
    r'\textit{ABBA}', r'\textit{BABA}', r'\textit{BAAA}', r'\textit{ABAA}',
    r'\textit{D+}', r'\textit{P-value}',
]
# Intialize a table header.
header = r'''\begin{longtblr}
{
colspec={XXXXXXXXX},
columns={halign=c},
width=\linewidth,
rowhead=1,
row{even}={gray9},
row{1}={brown9},
caption={Table S8: \textit{D+} results for the focal 72kb \textit{MUC19} region where the Yoruba in Ibadan, Nigeria population (YRI) is P1, every non-African population as P2, and the Vindija Neanderthal (VIN) as P3, where ancestral states were polarized using the ancestral allele calls inferred from a six primate alignment using the EPO pipeline. The \textit{P-value} represents if the observed \textit{D+} is significantly different than zero, where \textit{P-values} were computed by building a \textit{z}-distribution of \textit{D+} values from each non-overlapping 72kb window of comparable effective sequence length. After accounting for 19 multiple-comparisons using the Bonferroni correction, a \textit{P-value} less than 0.00263 is considered significant. No comparisons were found to be significant.},
}'''+'\n'\
+ r'\hline'+'\n'\
+ r' & '.join(f'{col}' for col in cols)+r' \\'+'\n'\
+ r'\hline'+'\n'\
# Open the table.
table = open('./supp_tables/p1_yri_p2_ooa_p3_vin_72kb.tex', 'w')
# Write the header.
table.write(header)
# For every row...
for i in range(mat.shape[0]):
    # Write the results.
    table.write(
        r' & '.join(f'{mat[i, j]}' for j in range(3))+r' & '\
        + r' & '.join('{:.5f}'.format(mat[i, j]).rstrip('0').rstrip('.') for j in range(3, mat.shape[1]))\
        + r' \\'+'\n'+r'\hline'+'\n'
        )
# Write the footer.
table.write(r'\end{longtblr}'+'\n')
# Close the table file.
table.close()

# %% [markdown]
# Table S8: \textit{D+} results for the focal 72kb \textit{MUC19} region where the Yoruba in Ibadan, Nigeria population (YRI) is P1, every non-African population as P2, and the Vindija Neanderthal (VIN) as P3, where ancestral states were polarized using the ancestral allele calls inferred from a six primate alignment using the EPO pipeline. The \textit{P-value} represents if the observed \textit{D+} is significantly different than zero, where \textit{P-values} were computed by building a \textit{z}-distribution of \textit{D+} values from each non-overlapping 72kb window of comparable effective sequence length. After accounting for 19 multiple-comparisons using the Bonferroni correction, a \textit{P-value} less than 0.00263 is considered significant. No comparisons were found to be significant.

# %%
df.iloc[:, [0, 1, 2, 3, 4, 5, 6, 9, 12]]
# Out:
#      P1   P2   P3       ABBA       BABA       BAAA       ABAA      $D+$  \
# 0   YRI  PEL  VIN  17.070602  12.206359  28.422318  27.120711  0.072693
# 1   YRI  MXL  VIN  22.041540  14.996691  31.908402  30.139884  0.088946
# 2   YRI  CLM  VIN   7.764184   9.478477  21.984067  24.647730 -0.068540
# 3   YRI  PUR  VIN   8.907096   9.309963  22.762487  23.260795 -0.014028
# 4   YRI  BEB  VIN  12.515517  11.084585  24.942466  25.030052  0.018259
# 5   YRI  STU  VIN  10.375658   9.842298  23.720656  23.504834  0.011108
# 6   YRI  ITU  VIN   9.971303   9.842354  23.265353  23.615707 -0.003320
# 7   YRI  PJL  VIN   6.676963   8.361280  20.895110  21.832321 -0.045382
# 8   YRI  GIH  VIN   9.282621   9.440365  22.926521  23.202299 -0.006685
# 9   YRI  CHB  VIN   6.978807   6.041891  20.802050  21.075400  0.012087
# 10  YRI  KHV  VIN   9.940049   7.817784  22.954920  22.560770  0.039770
# 11  YRI  CHS  VIN   7.159877   6.455578  21.064484  21.314418  0.008114
# ...

# %% [markdown]
# ## Table S9

# %%
# Load the dataframe.
df = pd.read_csv('./dataframes/p1_yri_p2_ooa_p3_cha_72kb.csv')
# Convert the dataframe to a numpy matrix.
mat = df.to_numpy()[:, [0, 1, 2, 3, 4, 5, 6, 9, 12]]
# Intialize the columns.
cols = [
    'P1', 'P2', 'P3',
    r'\textit{ABBA}', r'\textit{BABA}', r'\textit{BAAA}', r'\textit{ABAA}',
    r'\textit{D+}', r'\textit{P-value}',
]
# Intialize a table header.
header = r'''\begin{longtblr}
{
colspec={XXXXXXXXX},
columns={halign=c},
width=\linewidth,
rowhead=1,
row{even}={gray9},
row{1}={brown9},
caption={Table S9: \textit{D+} results for the focal 72kb \textit{MUC19} region where the Yoruba in Ibadan, Nigeria population (YRI) is P1, every non-African population as P2, and the Chagyrskaya Neanderthal (CHA) as P3, where ancestral states were polarized using the ancestral allele calls inferred from a six primate alignment using the EPO pipeline. The \textit{P-value} represents if the observed \textit{D+} is significantly different than zero, where \textit{P-values} were computed by building a \textit{z}-distribution of \textit{D+} values from each non-overlapping 72kb window of comparable effective sequence length. After accounting for 19 multiple-comparisons using the Bonferroni correction, a \textit{P-value} less than 0.00263 is considered significant. No comparisons were found to be significant.},
}'''+'\n'\
+ r'\hline'+'\n'\
+ r' & '.join(f'{col}' for col in cols)+r' \\'+'\n'\
+ r'\hline'+'\n'\
# Open the table.
table = open('./supp_tables/p1_yri_p2_ooa_p3_cha_72kb.tex', 'w')
# Write the header.
table.write(header)
# For every row...
for i in range(mat.shape[0]):
    # Write the results.
    table.write(
        r' & '.join(f'{mat[i, j]}' for j in range(3))+r' & '\
        + r' & '.join('{:.5f}'.format(mat[i, j]).rstrip('0').rstrip('.') for j in range(3, mat.shape[1]))\
        + r' \\'+'\n'+r'\hline'+'\n'
        )
# Write the footer.
table.write(r'\end{longtblr}'+'\n')
# Close the table file.
table.close()

# %% [markdown]
# Table S9: \textit{D+} results for the focal 72kb \textit{MUC19} region where the Yoruba in Ibadan, Nigeria population (YRI) is P1, every non-African population as P2, and the Chagyrskaya Neanderthal (CHA) as P3, where ancestral states were polarized using the ancestral allele calls inferred from a six primate alignment using the EPO pipeline. The \textit{P-value} represents if the observed \textit{D+} is significantly different than zero, where \textit{P-values} were computed by building a \textit{z}-distribution of \textit{D+} values from each non-overlapping 72kb window of comparable effective sequence length. After accounting for 19 multiple-comparisons using the Bonferroni correction, a \textit{P-value} less than 0.00263 is considered significant. No comparisons were found to be significant.

# %%
df.iloc[:, [0, 1, 2, 3, 4, 5, 6, 9, 12]]
# Out:
#      P1   P2   P3       ABBA       BABA       BAAA       ABAA      $D+$  \
# 0   YRI  PEL  CHA  16.965523  11.892865  28.519172  27.422168  0.072756
# 1   YRI  MXL  CHA  21.905635  14.607747  31.994068  30.561632  0.088124
# 2   YRI  CLM  CHA   7.683708   9.303290  22.085131  24.803709 -0.067916
# 3   YRI  PUR  CHA   8.805400   9.131611  22.859509  23.449608 -0.014263
# 4   YRI  BEB  CHA  12.435279  10.846240  25.041922  25.280725  0.018345
# 5   YRI  STU  CHA  10.274998   9.631752  23.818979  23.714132  0.011093
# 6   YRI  ITU  CHA   9.855801   9.648829  23.356413  23.834899 -0.004071
# 7   YRI  PJL  CHA   6.590953   8.208430  21.001326  21.966025 -0.044700
# 8   YRI  GIH  CHA   9.192568   9.254776  23.025137  23.394923 -0.006660
# 9   YRI  CHB  CHA   6.962367   5.878944  20.931174  21.121348  0.016272
# 10  YRI  KHV  CHA   9.899633   7.605020  23.077172  22.677761  0.042587
# 11  YRI  CHS  CHA   7.143717   6.288426  21.193717  21.364220  0.012231
# ...

# %% [markdown]
# ## Table S10

# %%
# Load the dataframe.
df = pd.read_csv('./dataframes/na19789_longest_tract_haplotype_divergence_748kb.csv')
# Convert the dataframe to a numpy matrix.
mat = df.to_numpy()[:, [2, 3, 4, 5, 6, 11, 12]]
# Intialize the columns.
cols = [
    'Archaic',
    r'{PW-Diffs. \\ (Chr. 1)}', r'{PW-Diffs. \\ (Chr. 2)}',
    r'{Seq. Div. \\ (Chr. 1)}', r'{Seq. Div. \\ (Chr. 2)}',
    r'{\textit{P-value} \\ (Chr. 1)}', r'{\textit{P-value} \\ (Chr. 2)}',
]
# Intialize a table header.
header = r'''\begin{longtblr}
{
colspec={XXXXXXX},
columns={halign=c},
width=\linewidth,
rowhead=1,
row{even}={gray9},
row{1}={brown9},
caption={Table S10: Archaic affinities for the longest introgressed tract found in an MXL individual (i.e., NA19789) that overlaps with the NCBI RefSeq coordinates for \textit{MUC19} (hg19, Chr12:40787196-40964559). The \textit{P-value} represents the proportion of non-overlapping 748kb windows of comparable  effective sequence length with a sequence divergence less than or equal to what is observed for the 748kb longest introgressed tract. After accounting for four  multiple-comparisons per chromosome using the Bonferroni correction, a \textit{P-value} less than 0.0125 is considered significant.},
}'''+'\n'\
+ r'\hline'+'\n'\
+ r' & '.join(f'{col}' for col in cols)+r' \\'+'\n'\
+ r'\hline'+'\n'\
# Open the table.
table = open('./supp_tables/na19789_longest_tract_haplotype_divergence_748kb.tex', 'w')
# Write the header.
table.write(header)
# For every row...
for i in range(mat.shape[0]):
    # Write the results.
    table.write(
        r' & '.join(f'{mat[i, j]}' for j in range(1))+r' & '\
        + r' & '.join(f'{round(mat[i, j], 5)}' for j in range(1, mat.shape[1]))\
        + r' \\'+'\n'+r'\hline'+'\n'
        )
# Write the footer.
table.write(r'\end{longtblr}'+'\n')
# Close the table file.
table.close()

# %% [markdown]
# Table S10: Archaic affinities for the longest introgressed tract found in an MXL individual (i.e., NA19789) that overlaps with the NCBI RefSeq coordinates for \textit{MUC19} (hg19, Chr12:40787196-40964559). The \textit{P-value} represents the proportion of non-overlapping 748kb windows of comparable  effective sequence length with a sequence divergence less than or equal to what is observed for the 748kb longest introgressed tract. After accounting for four  multiple-comparisons per chromosome using the Bonferroni correction, a \textit{P-value} less than 0.0125 is considered significant.

# %%
df.iloc[:, [2, 3, 4, 5, 6, 11, 12]]
# Out:
#              Archaic  748kb (Pairwise Differences Chr. 1)  \
# 0          Denisovan                                724.5
# 1        Altai Nean.                                669.0
# 2  Chagyrskaya Nean.                                758.5
# 3      Vindija Nean.                                764.5
#
#    748kb (Pairwise Differences Chr. 2)  748kb (Sequence Divergence Chr. 1)  \
# 0                                437.5                            0.001357
# 1                                478.0                            0.001252
# 2                                351.5                            0.001421
# 3                                356.5                            0.001432
#
#    748kb (Sequence Divergence Chr. 2)  $P-value$ (Chr. 1)  $P-value$ (Chr. 2)
# 0                            0.000819            0.446501            0.017258
# 1                            0.000895            0.382805            0.048949
# ...

# %% [markdown]
# ## Table S11

# %%
# Load the dataframe.
df = pd.read_csv('./dataframes/african_and_introgressed_inds_heterozygous_sites_72kb.csv')
# Convert the dataframe to a numpy matrix.
mat = df.to_numpy()[:, [0, 1, 4]]
# Intialize the columns.
cols = [
    'Group', 'Average Number of Het. Sites', r'\textit{P-value}',
]
# Intialize a list of p-values.
pvals = [r'$4.549e^{-1}$', r'$3.242e^{-5}$', r'$1.167e^{-3}$']
# Intialize a table header.
header = r'''\begin{longtblr}
{
colspec={XXX},
columns={halign=c},
width=\linewidth,
rowhead=1,
row{even}={gray9},
row{1}={brown9},
caption={Table S11: Average number of heterozygous sites amongst all African individuals ($n = 504$), heterozygous individuals ($n = 255$) who carry one copy of the \textit{Denisovan-like} haplotype, and homozygous individuals ($n = 16$) who carry two copies of the \textit{Denisovan-like} haplotype for the focal 72kb \textit{MUC19} region. For the African and heterozygous individuals the \textit{P-value} represents the proportion of non-overlapping 72kb windows of comparable effective sequence length with an average number of heterozygous greater than or equal to what is observed at the 72kb \textit{MUC19} region, and for homozygous individuals the \textit{P-value} represents the proportion of windows with an average number of heterozygous sites less than or equal to what is observed at the 72kb \textit{MUC19} region. After accounting for three multiple-comparisons using the Bonferroni correction, a \textit{P-value} less than 0.0167 is considered significant.},
}'''+'\n'\
+ r'\hline'+'\n'\
+ r' & '.join(f'{col}' for col in cols)+r' \\'+'\n'\
+ r'\hline'+'\n'\
# Open the table.
table = open('./supp_tables/african_and_introgressed_inds_heterozygous_sites_72kb.tex', 'w')
# Write the header.
table.write(header)
# For every row...
for i in range(mat.shape[0]):
    # Write the results.
    table.write(
        r' & '.join(f'{mat[i, j]}' for j in range(1))+r' & '\
        + r' & '.join('{:.5f}'.format(mat[i, j]).rstrip('0').rstrip('.') for j in range(1, 2))\
        + r' & {0}'.format(pvals[i])\
        + r' \\'+'\n'+r'\hline'+'\n'
        )
# Write the footer.
table.write(r'\end{longtblr}'+'\n')
# Close the table file.
table.close()

# %% [markdown]
# Table S11: Average number of heterozygous sites amongst all African individuals ($n = 504$), heterozygous individuals ($n = 255$) who carry one copy of the \textit{Denisovan-like} haplotype, and homozygous individuals ($n = 16$) who carry two copies of the \textit{Denisovan-like} haplotype for the focal 72kb \textit{MUC19} region. For the African and heterozygous individuals the \textit{P-value} represents the proportion of non-overlapping 72kb windows of comparable effective sequence length with an average number of heterozygous greater than or equal to what is observed at the 72kb \textit{MUC19} region, and for homozygous individuals the \textit{P-value} represents the proportion of windows with an average number of heterozygous sites less than or equal to what is observed at the 72kb \textit{MUC19} region. After accounting for three multiple-comparisons using the Bonferroni correction, a \textit{P-value} less than 0.0167 is considered significant.

# %%
df.iloc[:, [0, 1, 4]]
# Out:
#                 Group  $MUC19$ (Average Number of Heterozygous Sites)  \
# 0       African Inds.                                       50.158730
# 1  Heterozygous Inds.                                      218.494118
# 2    Homozygous Inds.                                        2.625000
#
#    $P-value$
# 0   0.454858
# 1   0.000032
# 2   0.001167

# %% [markdown]
# ## Table S12

# %%
# Load the dataframe.
df = pd.read_csv('./dataframes/archaic_heterozygous_sites_72kb.csv')
# Convert the dataframe to a numpy matrix.
mat = df.to_numpy()[:, [0, 1, 4]]
# Intialize the columns.
cols = [
    'Archaic', 'Number of Het. Sites', r'\textit{P-value}',
]
# Intialize a table header.
header = r'''\begin{longtblr}
{
colspec={XXX},
columns={halign=c},
width=\linewidth,
rowhead=1,
row{even}={gray9},
row{1}={brown9},
caption={Table S12: Number of heterozygous sites amongst all high-coverage archaic individuals observed at the focal 72kb \textit{MUC19} region. The \textit{P-value} represents the proportion of non-overlapping 72kb windows of comparable effective sequence length where the number of heterozygous sites is greater than or equal to what is observed at the 72kb \textit{MUC19} region. After accounting for four multiple-comparisons using the Bonferroni correction, a \textit{P-value} less than 0.0125 is considered significant.},
}'''+'\n'\
+ r'\hline'+'\n'\
+ r' & '.join(f'{col}' for col in cols)+r' \\'+'\n'\
+ r'\hline'+'\n'\
# Open the table.
table = open('./supp_tables/archaic_heterozygous_sites_72kb.tex', 'w')
# Write the header.
table.write(header)
# For every row...
for i in range(mat.shape[0]):
    # Write the results.
    table.write(
        r' & '.join(f'{mat[i, j]}' for j in range(1))+r' & '\
        + r' & '.join('{:.5f}'.format(mat[i, j]).rstrip('0').rstrip('.') for j in range(1, mat.shape[1]))\
        + r' \\'+'\n'+r'\hline'+'\n'
        )
# Write the footer.
table.write(r'\end{longtblr}'+'\n')
# Close the table file.
table.close()

# %% [markdown]
# Table S12: Number of heterozygous sites amongst all high-coverage archaic individuals observed at the focal 72kb \textit{MUC19} region. The \textit{P-value} represents the proportion of non-overlapping 72kb windows of comparable effective sequence length where the number of heterozygous sites is greater than or equal to what is observed at the 72kb \textit{MUC19} region. After accounting for four multiple-comparisons using the Bonferroni correction, a \textit{P-value} less than 0.0125 is considered significant.

# %%
df.iloc[:, [0, 1, 4]]
# Out:
#              Archaic  $MUC19$ (Heterozygous Sites)  $P-value$
# 0          Denisovan                            12   0.279339
# 1        Altai Nean.                             1   0.798769
# 2  Chagyrskaya Nean.                           182   0.000227
# 3      Vindija Nean.                           181   0.000389

# %% [markdown]
# ## Table S13

# %%
# Load the dataframe.
df = pd.read_csv('./dataframes/pap_scores_72kb.csv')
# Convert the dataframe to a numpy matrix.
mat = df.to_numpy()
# Intialize the columns.
cols = df.columns.values
# Intialize a table header.
header = r'''\begin{longtblr}
{
colspec={XXXXXX},
columns={halign=c},
width=\linewidth,
rowhead=1,
row{even}={gray9},
row{1}={brown9},
caption={Table S13: Pseudo-Ancestry Painting (PAP) results for the Chagyrskaya (CHA) and Vindija (VIN) Neanderthals as the possible targets and the sequenced Denisovan (DEN), Altai Neanderthal (ALT), a MXL individual (i.e., NA19664) who carries two copies of the \textit{Denisovan-like} haplotype, and a YRI individual (i.e., NA19190) who carries two copies of the \textit{human-like} haplotype as potential sources. For a given set of two source individuals and a target individual, a site is considered a PAP site if the heterozygous site in the target individual can be explained by one source individual being homozygous for the derived allele and the other source individual being homozygous for the ancestral allele. The PAP score represents the number of PAP sites normalized by the total number of heterozygous sites.},
}'''+'\n'\
+ r'\hline'+'\n'\
+ r' & '.join(f'{col}' for col in cols)+r' \\'+'\n'\
+ r'\hline'+'\n'\
# Open the table.
table = open('./supp_tables/pap_scores_72kb.tex', 'w')
# Write the header.
table.write(header)
# For every row...
for i in range(mat.shape[0]):
    # Write the results.
    table.write(
        r' & '.join(f'{mat[i, j]}' for j in range(3))+r' & '\
        + r' & '.join('{:.5f}'.format(mat[i, j]).rstrip('0').rstrip('.') for j in range(3, mat.shape[1]))\
        + r' \\'+'\n'+r'\hline'+'\n'
        )
# Write the footer.
table.write(r'\end{longtblr}'+'\n')
# Close the table file.
table.close()

# %% [markdown]
# Table S13: Pseudo-Ancestry Painting (PAP) results for the Chagyrskaya (CHA) and Vindija (VIN) Neanderthals as the possible targets and the sequenced Denisovan (DEN), Altai Neanderthal (ALT), a MXL individual (i.e., NA19664) who carries two copies of the \textit{Denisovan-like} haplotype, and a YRI individual (i.e., NA19190) who carries two copies of the \textit{human-like} haplotype as potential sources. For a given set of two source individuals and a target individual, a site is considered a PAP site if the heterozygous site in the target individual can be explained by one source individual being homozygous for the derived allele and the other source individual being homozygous for the ancestral allele. The PAP score represents the number of PAP sites normalized by the total number of heterozygous sites.

# %%
df
# Out:
#   Source 1 Source 2 Target  Total Sites  PAP Sites  PAP Score
# 0      DEN      ALT    CHA          181        158   0.872928
# 1      DEN      ALT    VIN          180        159   0.883333
# 2      MXL      YRI    CHA          181        169   0.933702
# 3      MXL      YRI    VIN          180        168   0.933333

# %% [markdown]
# ## Table S14

# %%
# Load the dataframe.
df = pd.read_csv('./dataframes/p1_alt_p2_nea_p3_den_72kb.csv')
# Convert the dataframe to a numpy matrix.
mat = df.to_numpy()[:, [0, 1, 2, 3, 4, 5, 6, 9, 12]]
# Intialize the columns.
cols = [
    'P1', 'P2', 'P3',
    r'\textit{ABBA}', r'\textit{BABA}', r'\textit{BAAA}', r'\textit{ABAA}',
    r'\textit{D+}', r'\textit{P-value}',
]
# Intialize a table header.
header = r'''\begin{longtblr}
{
colspec={XXXXXXXXX},
columns={halign=c},
width=\linewidth,
rowhead=1,
row{even}={gray9},
row{1}={brown9},
caption={Table S14: \textit{D+} results for the focal 72kb \textit{MUC19} region where the Altai Neanderthal (ALT) is P1, either the Chagyrskaya (CHA) or Vindija (VIN) Neanderthal as P2, and the sequenced Denisovan (DEN) as P3, where ancestral states were polarized using the ancestral allele calls inferred from a six primate alignment using the EPO pipeline. The \textit{P-value} represents if the observed \textit{D+} is significantly different than zero, where \textit{P-values} were computed by building a \textit{z}-distribution of \textit{D+} values from each non-overlapping 72kb window of comparable effective sequence length. After accounting for two multiple-comparisons using the Bonferroni correction, a \textit{P-value} less than 0.025 is considered significant. A significant and positive \textit{D+} result suggests that P2 and the sequenced Denisovan share more derived and ancestral alleles than expected.},
}'''+'\n'\
+ r'\hline'+'\n'\
+ r' & '.join(f'{col}' for col in cols)+r' \\'+'\n'\
+ r'\hline'+'\n'\
# Open the table.
table = open('./supp_tables/p1_alt_p2_nea_p3_den_72kb.tex', 'w')
# Write the header.
table.write(header)
# For every row...
for i in range(mat.shape[0]):
    # Write the results.
    table.write(
        r' & '.join(f'{mat[i, j]}' for j in range(3))+r' & '\
        + r' & '.join('{:.5f}'.format(mat[i, j]).rstrip('0').rstrip('.') for j in range(3, mat.shape[1]))\
        + r' \\'+'\n'+r'\hline'+'\n'
        )
# Write the footer.
table.write(r'\end{longtblr}'+'\n')
# Close the table file.
table.close()

# %% [markdown]
# Table S14: \textit{D+} results for the focal 72kb \textit{MUC19} region where the Altai Neanderthal (ALT) is P1, either the Chagyrskaya (CHA) or Vindija (VIN) Neanderthal as P2, and the sequenced Denisovan (DEN) as P3, where ancestral states were polarized using the ancestral allele calls inferred from a six primate alignment using the EPO pipeline. The \textit{P-value} represents if the observed \textit{D+} is significantly different than zero, where \textit{P-values} were computed by building a \textit{z}-distribution of \textit{D+} values from each non-overlapping 72kb window of comparable effective sequence length. After accounting for two multiple-comparisons using the Bonferroni correction, a \textit{P-value} less than 0.025 is considered significant. A significant and positive \textit{D+} result suggests that P2 and the sequenced Denisovan share more derived and ancestral alleles than expected.

# %%
df.iloc[:, [0, 1, 2, 3, 4, 5, 6, 9, 12]]
# Out:
#     P1   P2   P3   ABBA  BABA   BAAA   ABAA      $D+$  $P-value$
# 0  ALT  CHA  DEN  40.25   0.0  44.00  11.25  0.764398   0.019778
# 1  ALT  VIN  DEN  41.50   0.0  43.75   9.75  0.794737   0.012173

# %% [markdown]
# ## Table S15

# %%
# Load the dataframe.
df = pd.read_csv('./dataframes/p1_cha_p2_vin_p3_arc_72kb.csv')
# Convert the dataframe to a numpy matrix.
mat = df.to_numpy()[:, [0, 1, 2, 3, 4, 5, 6, 9, 12]]
# Intialize the columns.
cols = [
    'P1', 'P2', 'P3',
    r'\textit{ABBA}', r'\textit{BABA}', r'\textit{BAAA}', r'\textit{ABAA}',
    r'\textit{D+}', r'\textit{P-value}',
]
# Intialize a table header.
header = r'''\begin{longtblr}
{
colspec={XXXXXXXXX},
columns={halign=c},
width=\linewidth,
rowhead=1,
row{even}={gray9},
row{1}={brown9},
caption={Table S15: \textit{D+} results for the focal 72kb \textit{MUC19} region where the Vindija Neanderthal (VIN) is P1, the Chagyrskaya Neanderthal (CHA) is P2, and either the sequenced Denisovan (DEN) or the Altai Neanderthal (ALT) as P3, where ancestral states were polarized using the ancestral allele calls inferred from a six primate alignment using the EPO pipeline. The \textit{P-value} represents if the observed \textit{D+} is significantly different than zero, where \textit{P-values} were computed by building a \textit{z}-distribution of \textit{D+} values from each non-overlapping 72kb window of comparable effective sequence length. After accounting for two multiple-comparisons using the Bonferroni correction, a \textit{P-value} less than 0.025 is considered significant. No comparisons were found to be significant.},
}'''+'\n'\
+ r'\hline'+'\n'\
+ r' & '.join(f'{col}' for col in cols)+r' \\'+'\n'\
+ r'\hline'+'\n'\
# Open the table.
table = open('./supp_tables/p1_cha_p2_vin_p3_arc_72kb.tex', 'w')
# Write the header.
table.write(header)
# For every row...
for i in range(mat.shape[0]):
    # Write the results.
    table.write(
        r' & '.join(f'{mat[i, j]}' for j in range(3))+r' & '\
        + r' & '.join('{:.5f}'.format(mat[i, j]).rstrip('0').rstrip('.') for j in range(3, mat.shape[1]))\
        + r' \\'+'\n'+r'\hline'+'\n'
        )
# Write the footer.
table.write(r'\end{longtblr}'+'\n')
# Close the table file.
table.close()

# %% [markdown]
# Table S15: \textit{D+} results for the focal 72kb \textit{MUC19} region where the Vindija Neanderthal (VIN) is P1, the Chagyrskaya Neanderthal (CHA) is P2, and either the sequenced Denisovan (DEN) or the Altai Neanderthal (ALT) as P3, where ancestral states were polarized using the ancestral allele calls inferred from a six primate alignment using the EPO pipeline. The \textit{P-value} represents if the observed \textit{D+} is significantly different than zero, where \textit{P-values} were computed by building a \textit{z}-distribution of \textit{D+} values from each non-overlapping 72kb window of comparable effective sequence length. After accounting for two multiple-comparisons using the Bonferroni correction, a \textit{P-value} less than 0.025 is considered significant. No comparisons were found to be significant.

# %%
df.iloc[:, [0, 1, 2, 3, 4, 5, 6, 9, 12]]
# Out:
#     P1   P2   P3   ABBA   BABA   BAAA   ABAA      $D+$  $P-value$
# 0  CHA  VIN  DEN  20.00  19.75  25.50  25.25  0.005525   0.494139
# 1  CHA  VIN  ALT  19.75  19.50  25.75  26.00  0.000000   0.500000

# %% [markdown]
# ## Table S16

# %%
# Load the dataframe.
df = pd.read_csv('./dataframes/ancient_sample_info.csv')
# Convert the dataframe to a numpy matrix.
mat = df.to_numpy()
# Extract the columns.
cols = df.columns.values
# Intialize a table header.
header = r'''\begin{longtblr}
{
colspec={XXXXX},
columns={halign=c},
width=\linewidth,
rowhead=1,
row{even}={gray9},
row{1}={brown9},
caption={Table S16: Metadata for each of the 23 Ancient American genomes used in this study.},
}'''+'\n'\
+ r'\hline'+'\n'\
+ r' & '.join(f'{col}' for col in cols)+r' \\'+'\n'\
+ r'\hline'+'\n'\
# Open the table.
table = open('./supp_tables/ancient_sample_info.tex', 'w')
# Write the header.
table.write(header)
# For every row...
for i in range(mat.shape[0]):
    # Write the results.
    table.write(
        r' & '.join(f'{mat[i, j]}' for j in range(3))+r' & '\
        + r' & '.join('{:.5f}'.format(float(mat[i, j])).rstrip('0').rstrip('.') for j in range(3, 4))+r' & '\
        +r' & '.join(f'{mat[i, j]}' for j in range(4, mat.shape[1]))\
        + r' \\'+'\n'+r'\hline'+'\n'
        )
# Write the footer.
table.write(r'\end{longtblr}'+'\n')
# Close the table file.
table.close()

# %% [markdown]
# Table S16: Metadata for each of the 23 Ancient American genomes used in this study.

# %%
df
# Out:
#     Population          ID Age (years)  Coverage (x)  \
# 0       Alaska        USR1      11,500         17.00
# 1   California       CR-01       1,111          8.36
# 2   California       CT-01         387          6.68
# 3   California        NC_C       1,450          1.12
# 4   California       PS-06       1,570          4.12
# 5   California       SC-05       1,101         13.67
# 6   California       SM-02         826          7.38
# 7   California       SN-13         881          1.74
# 8   California       SN-17       4,517          7.46
# 9   California       SN-44       4,646          9.36
# 10     Montana      Clovis      12,500         14.40
# 11     Ontario       CK-13       4,267          3.02
# 12   Patagonia  ERR2270782       1,000          7.80
# 13   Patagonia  ERR2270783       1,000          3.50
# 14   Patagonia  ERR2270784       1,000          1.70
# 15   Patagonia  ERR2270785       1,000          9.10
# 16        Peru  SRR8144644       1,800          3.34
# ...

# %% [markdown]
# ## Table S17

# %%
# Load the dataframe.
df = pd.read_csv('./dataframes/tgp_sgdp_six_den_der_mis_mut_freqs_72kb.csv')
df = df.drop(['Position (hg19)', 'rsID', 'Reference Allele', 'Alternative Allele', 'Ancestral Allele', 'Derived Allele', r'Anc. AA $\rightarrow$ Der. AA'], axis=1)
# Convert the dataframe to a numpy matrix.
mat = df.T.to_numpy()
idx = df.T.index.values
# Intialize the columns.
cols = [
    'Population',
    r'{40808672 \\ rs4768252}', r'{40808726 \\ rs4768253}', r'{40815060 \\ rs149221842}',
    r'{40821795 \\ rs61736852}', r'{40821847 \\ rs11564170}', r'{40821871 \\ rs17467284}',
]
# Intialize a table header.
header = r'''\begin{longtblr}
{
colspec={XXXXXXX},
columns={halign=c},
width=\linewidth,
rowhead=1,
row{even}={gray9},
row{1}={brown9},
caption={Table S17: Global frequencies of the six Denisovan-specific derived missense mutations in Papuans, 22 Indigenous Americans from the SGDP, and the TGP.},
}'''+'\n'\
+ r'\hline'+'\n'\
+ r' & '.join(f'{col}' for col in cols)+r' \\'+'\n'\
+ r'\hline'+'\n'\
# Open the table.
table = open('./supp_tables/tgp_sgdp_six_den_der_mis_mut_freqs_72kb.tex', 'w')
# Write the header.
table.write(header)
# For every row...
for i in range(mat.shape[0]):
    # Write the results.
    table.write(
        r'{0} & '.format(idx[i])\
        + r' & '.join('{:.5f}'.format(mat[i, j]).rstrip('0').rstrip('.') for j in range(0, mat.shape[1]))\
        + r' \\'+'\n'+r'\hline'+'\n'
        )
# Write the footer.
table.write(r'\end{longtblr}'+'\n')
# Close the table file.
table.close()

# %% [markdown]
# Table S17: Global frequencies of the six Denisovan-specific derived missense mutations in Papuans, 22 Indigenous Americans from the SGDP, and the TGP.

# %%
df.T
# Out:
#                             0         1         2         3         4  \
# Papuan ($n$ = 15)    0.100000  0.100000  0.100000  0.100000  0.100000
# SGDP AMR ($n$ = 22)  0.363636  0.363636  0.363636  0.363636  0.363636
# LWK                  0.000000  0.000000  0.000000  0.000000  0.000000
# GWD                  0.000000  0.000000  0.000000  0.000000  0.000000
# MSL                  0.000000  0.000000  0.000000  0.000000  0.000000
# ESN                  0.000000  0.000000  0.000000  0.000000  0.000000
# YRI                  0.000000  0.000000  0.000000  0.000000  0.000000
# BEB                  0.156977  0.168605  0.156977  0.139535  0.139535
# STU                  0.112745  0.112745  0.112745  0.112745  0.112745
# ITU                  0.112745  0.112745  0.107843  0.102941  0.102941
# PJL                  0.052083  0.052083  0.052083  0.052083  0.052083
# GIH                  0.097087  0.101942  0.097087  0.087379  0.087379
# ...

# %% [markdown]
# ## Table S18

# %%
# Load the dataframe.
df = pd.read_csv('./dataframes/ancient_americans_genos_six_den_der_mis_muts_72kb.csv')
df.to_csv('./supp_tables/S18.csv', index=False)

# %% [markdown]
# Genotypes at the six Denisovan-specific derived missense mutations for the 23 Ancient Indigenous American genomes. Note that missing data is denoted by a ".".

# %%
df
# Out:
#    Position (hg19)         rsID Reference Allele Alternative Allele  \
# 0         40808672    rs4768252                C                  T
# 1         40808726    rs4768253                C                  T
# 2         40815060  rs149221842                C                  T
# 3         40821795   rs61736852                G                  A
# 4         40821847   rs11564170                C                  A
# 5         40821871   rs17467284                G                  T
#
#   Ancestral Allele Derived Allele Anc. AA $\rightarrow$ Der. AA USR1 CK-13  \
# 0                C              T           Ser$\rightarrow$Leu  C/T     .
# 1                C              T           Thr$\rightarrow$Met  C/C   T/T
# 2                C              T           His$\rightarrow$Tyr  C/C     .
# 3                G              A           Glu$\rightarrow$Lys  G/G     .
# 4                C              A           Thr$\rightarrow$Lys  C/C   A/A
# ...

# %% [markdown]
# ## Table S19

# %%
# Load the dataframe.
df = pd.read_csv('./dataframes/sgdp_six_den_der_mis_mut_freqs_72kb.csv')
df.to_csv('./supp_tables/S19.csv', index=False)

# %% [markdown]
# Population frequencies of the six Denisovan-specific missense mutations in Papuans and Indigenous American populations in the TGP.

# %%
df
# Out:
#    Position (hg19)         rsID Reference Allele Alternative Allele  \
# 0         40808672    rs4768252                C                  T
# 1         40808726    rs4768253                C                  T
# 2         40815060  rs149221842                C                  T
# 3         40821795   rs61736852                G                  A
# 4         40821847   rs11564170                C                  A
# 5         40821871   rs17467284                G                  T
#
#   Ancestral Allele Derived Allele Anc. AA $\rightarrow$ Der. AA  \
# 0                C              T           Ser$\rightarrow$Leu
# 1                C              T           Thr$\rightarrow$Met
# 2                C              T           His$\rightarrow$Tyr
# 3                G              A           Glu$\rightarrow$Lys
# 4                C              A           Thr$\rightarrow$Lys
# 5                G              T           Arg$\rightarrow$Leu
#
# ...

# %% [markdown]
# ## Table S20

# %%
# Load the dataframe.
df = pd.read_csv('./dataframes/hg38_muc19_short_read_repeats.csv')
df.to_csv('./supp_tables/S20.csv', index=False)

# %% [markdown]
# Number of repeat counts in the TGP inferred from short-read sequencing data.

# %%
df
# Out:
#      Individual Population Super Population  Repeat Counts
# 0       NA19731        MXL              AMR            835
# 1       HG01348        CLM              AMR            834
# 2       HG01396        PUR              AMR            831
# 3       HG02105        PEL              AMR            823
# 4       NA19729        MXL              AMR            823
# 5       NA19735        MXL              AMR            816
# 6       HG01303        PUR              AMR            807
# 7       HG02147        PEL              AMR            777
# 8       NA19794        MXL              AMR            763
# 9       HG02286        PEL              AMR            761
# 10      HG01571        PEL              AMR            756
# 11      HG02262        PEL              AMR            753
# 12      HG01935        PEL              AMR            746
# 13      NA19681        MXL              AMR            741
# 14      HG01927        PEL              AMR            727
# ...

# %% [markdown]
# ## Table S21

# %%
# Load the dataframe.
df = pd.read_csv('./dataframes/tgp_muc19_vntr_fet.csv')
# Convert the dataframe to a numpy matrix.
mat = df.to_numpy()
# Extract the columns.
cols = df.columns.values
# Intialize a table header.
header = r'''\begin{longtblr}
{
colspec={XXX},
columns={halign=c},
width=\linewidth,
rowhead=1,
row{even}={gray9},
row{1}={brown9},
caption={Table S21: Contingency table to assess if Admixed American populations have a greater proportion of individuals with repeat counts greater than or equal to the mean number of repeat counts amongst non-African populations. Significance was assessed by performing a Fisher’s exact test, odds ratio: 2.2, \textit{P-value}: $4.976e^{-11}$.},
}'''+'\n'\
+ r'\hline'+'\n'\
+ r' & '.join(f'{col}' for col in cols)+r' \\'+'\n'\
+ r'\hline'+'\n'\
# Open the table.
table = open('./supp_tables/tgp_muc19_vntr_fet.tex', 'w')
# Write the header.
table.write(header)
# For every row...
for i in range(mat.shape[0]):
    # Write the results.
    table.write(
        r' & '.join(f'{mat[i, j]}' for j in range(mat.shape[1]))\
        + r' \\'+'\n'+r'\hline'+'\n'
        )
# Write the footer.
table.write(r'\end{longtblr}'+'\n')
# Close the table file.
table.close()

# %% [markdown]
# Table S21: Contingency table to assess if Admixed American populations have a greater proportion of individuals with repeat counts greater than or equal to the mean number of repeat counts amongst non-African populations. Significance was assessed by performing a Fisher’s exact test, odds ratio: 2.2, \textit{P-value}: $4.976e^{-11}$.

# %%
df
# Out:
#          Population  Num. of Inds. $>=$ Mean Repeat Count  \
# 0  Admixed American                                   180
# 1       Non-African                                   490
#
#    Num. of Inds. $<$ Mean Repeat Count
# 0                                  167
# 1                                 1001

# %% [markdown]
# ## Table S22

# %%
# Load the dataframe.
df = pd.read_csv('./dataframes/hg38_muc19_long_read_repeats.csv')
df.to_csv('./supp_tables/S22.csv', index=False)

# %% [markdown]
# Total repeat lengths in the TGP inferred from long-read sequencing data.

# %%
df
# Out:
#     Super Population Individual  Total Repeat Length
# 0                AFR    HG01891                 8178
# 1                AFR    HG01891                 8692
# 2                AFR    HG02011                 8178
# 3                AFR    HG02011                 8632
# 4                AFR    HG02055                 8692
# 5                AFR    HG02055                10008
# 6                AFR    HG02145                10336
# 7                AFR    HG02145                 8692
# 8                AFR    HG02257                10336
# 9                AFR    HG02257                 8632
# 10               AFR    HG02486                 8692
# 11               AFR    HG02486                 8178
# 12               AFR    HG02559                 8178
# 13               AFR    HG02559                 8632
# 14               AFR    HG02572                10336
# 15               AFR    HG02572                 8692
# 16               AFR    HG02587                 8632
# ...

# %% [markdown]
# ## Table S23

# %%
# Load the dataframe.
df = pd.read_csv('./dataframes/hg38_muc19_long_vs_short_read_repeats.csv')
df.to_csv('./supp_tables/S23.csv', index=False)

# %% [markdown]
# Short-read repeat counts vs long-read repeat counts for the TGP individuals with both short-read and long-read sequencing data.

# %%
df
# Out:
#    Individual  Long Read Repeat Counts  Short Read Repeat Counts
# 0     NA19983                      305                    288.13
# 1     HG00096                      296                    298.00
# 2     HG02572                      313                    299.41
# 3     HG02622                      305                    301.07
# 4     HG02818                      304                    307.14
# 5     HG01258                      304                    308.89
# 6     HG01358                      305                    310.72
# 7     HG01891                      305                    313.67
# 8     HG02717                      333                    316.97
# 9     HG02630                      313                    318.45
# 10    NA19650                      296                    319.47
# 11    HG02011                      304                    319.54
# 12    HG02492                      304                    320.31
# ...
