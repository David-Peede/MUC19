# %% [markdown]
# # *D+*

# %%
# Import packages.
import analysis_functions as af
import pandas as pd
# Print version numbers.
print('pandas', pd.__version__)
# Out:
# pandas 1.4.2

# %%
# Intialize my pandas preferences.
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Load the genotype matricies.
tgp_72kb_gt, _ = af.load_hap_region('tgp_mod_arc_anc', 12, 40758000, 40830000)
arc_72kb_gt, _ = af.load_hap_region('arc_anc', 12, 40758000, 40830000)

# %% [markdown]
# ## ((YRI, OOA), Denisovan)

# %%
# Intialize sample configuration lists.
p1s = ['YRI']
p2s = [
    'PEL', 'MXL', 'CLM', 'PUR', # AMR.
    'BEB', 'STU', 'ITU', 'PJL', 'GIH', # SAS.
    'CHB', 'KHV', 'CHS', 'JPT', 'CDX', # EAS.    
    'TSI', 'CEU', 'IBS', 'GBR', 'FIN', # EUR.
]
p3s = ['DEN']
# Load the windowed results.
yri_ooa_den_winds = af.build_tgp_arc_scenario_window_dicc('tgp', p1s, p2s, p3s, 72)
# Calculate the observed results.
yri_ooa_den_obs = af.calculate_tgp_arc_scenarios(tgp_72kb_gt, yri_ooa_den_winds, p1s, p2s, p3s, 72)

# %%
# Compile the results summary.
af.build_tgp_arc_scenario_tables(yri_ooa_den_obs, yri_ooa_den_winds, p1s, p2s, p3s, 72)
# Out:
#      P1   P2   P3       ABBA      BABA       BAAA       ABAA       BBAA  \
# 0   YRI  PEL  DEN  23.393328  4.786520  35.842157  21.650926  59.190251
# 1   YRI  MXL  DEN  30.904767  4.670247  42.234845  22.479782  52.797562
# 2   YRI  CLM  DEN   9.524749  7.114780  24.347764  23.179718  70.684643
# 3   YRI  PUR  DEN  11.099826  6.491208  25.586049  21.414218  69.446359
# 4   YRI  BEB  DEN  16.469423  6.354543  29.672508  21.686612  65.359900
# 5   YRI  STU  DEN  13.305374  6.207879  27.355074  21.026098  67.677333
# 6   YRI  ITU  DEN  12.638526  6.514070  26.593637  21.370053  68.438771
# 7   YRI  PJL  DEN   7.609785  6.933859  22.327739  21.107832  72.704668
# 8   YRI  GIH  DEN  11.594997  6.497955  25.868932  21.268563  69.163475
# 9   YRI  CHB  DEN   7.673499  4.811893  22.032048  20.516631  73.000360
# 10  YRI  KHV  DEN  12.169776  4.858750  25.908904  20.679527  69.123504
# 11  YRI  CHS  DEN   8.019709  5.061640  22.458422  20.606966  72.573986
# ...

# %%
# Plot the results.
af.plot_tgp_arc_scenarios('YRI', 'DEN', yri_ooa_den_winds, yri_ooa_den_obs, r'$MUC19$', 72)

# %% [markdown]
# ## ((YRI, OOA), Altai Nean.)

# %%
# Intialize sample configuration lists.
p1s = ['YRI']
p2s = [
    'PEL', 'MXL', 'CLM', 'PUR', # AMR.
    'BEB', 'STU', 'ITU', 'PJL', 'GIH', # SAS.
    'CHB', 'KHV', 'CHS', 'JPT', 'CDX', # EAS.    
    'TSI', 'CEU', 'IBS', 'GBR', 'FIN', # EUR.
]
p3s = ['ALT']
# Load the windowed results.
yri_ooa_alt_winds = af.build_tgp_arc_scenario_window_dicc('tgp', p1s, p2s, p3s, 72)
# Calculate the observed results.
yri_ooa_alt_obs = af.calculate_tgp_arc_scenarios(tgp_72kb_gt, yri_ooa_alt_winds, p1s, p2s, p3s, 72)

# %%
# Compile the results summary.
af.build_tgp_arc_scenario_tables(yri_ooa_alt_obs, yri_ooa_alt_winds, p1s, p2s, p3s, 72)
# Out:
#      P1   P2   P3      ABBA       BABA       BAAA       ABAA      BBAA  \
# 0   YRI  PEL  ALT  6.896895  20.269826  20.576498  38.147358  6.011465
# 1   YRI  MXL  ALT  7.477286  26.050492  21.159288  45.907263  5.428675
# 2   YRI  CLM  ALT  4.759013  12.471680  19.060013  27.945454  7.527950
# 3   YRI  PUR  ALT  5.280649  12.760706  19.398282  27.233396  7.189681
# 4   YRI  BEB  ALT  5.750619  16.580184  19.586402  32.405416  7.001561
# 5   YRI  STU  ALT  5.480664  14.143791  19.531908  28.850808  7.056055
# 6   YRI  ITU  ALT  5.365015  13.866376  19.344272  28.643564  7.243691
# 7   YRI  PJL  ALT  4.878086  10.479938  18.833743  23.839530  7.754220
# 8   YRI  GIH  ALT  5.304319  13.044925  19.409340  27.559241  7.178623
# 9   YRI  CHB  ALT  6.026654   7.757551  19.120370  22.163475  7.467593
# 10  YRI  KHV  ALT  6.367775  11.319374  19.539188  26.481528  7.048775
# 11  YRI  CHS  ALT  5.978064   8.326345  19.231812  22.648611  7.356151
# ...

# %%
# Plot the results.
af.plot_tgp_arc_scenarios('YRI', 'ALT', yri_ooa_alt_winds, yri_ooa_alt_obs, r'$MUC19$', 72)

# %% [markdown]
# ## ((YRI, OOA), Chagyrskaya Nean.)

# %%
# Intialize sample configuration lists.
p1s = ['YRI']
p2s = [
    'PEL', 'MXL', 'CLM', 'PUR', # AMR.
    'BEB', 'STU', 'ITU', 'PJL', 'GIH', # SAS.
    'CHB', 'KHV', 'CHS', 'JPT', 'CDX', # EAS.    
    'TSI', 'CEU', 'IBS', 'GBR', 'FIN', # EUR.
]
p3s = ['CHA']
# Load the windowed results.
yri_ooa_cha_winds = af.build_tgp_arc_scenario_window_dicc('tgp', p1s, p2s, p3s, 72)
# Calculate the observed results.
yri_ooa_cha_obs = af.calculate_tgp_arc_scenarios(tgp_72kb_gt, yri_ooa_cha_winds, p1s, p2s, p3s, 72)

# %%
# Compile the results summary.
af.build_tgp_arc_scenario_tables(yri_ooa_cha_obs, yri_ooa_cha_winds, p1s, p2s, p3s, 72)
# Out:
#      P1   P2   P3       ABBA       BABA       BAAA       ABAA       BBAA  \
# 0   YRI  PEL  CHA  16.965523  11.892865  28.519172  27.422168  31.948420
# 1   YRI  MXL  CHA  21.905635  14.607747  31.994068  30.561632  28.473524
# 2   YRI  CLM  CHA   7.683708   9.303290  22.085131  24.803709  38.382462
# 3   YRI  PUR  CHA   8.805400   9.131611  22.859509  23.449608  37.608084
# 4   YRI  BEB  CHA  12.435279  10.846240  25.041922  25.280725  35.425670
# 5   YRI  STU  CHA  10.274998   9.631752  23.818979  23.714132  36.648613
# 6   YRI  ITU  CHA   9.855801   9.648829  23.356413  23.834899  37.111179
# 7   YRI  PJL  CHA   6.590953   8.208430  21.001326  21.966025  39.466266
# 8   YRI  GIH  CHA   9.192568   9.254776  23.025137  23.394923  37.442456
# 9   YRI  CHB  CHA   6.962367   5.878944  20.931174  21.121348  39.536419
# 10  YRI  KHV  CHA   9.899633   7.605020  23.077172  22.677761  37.390420
# 11  YRI  CHS  CHA   7.143717   6.288426  21.193717  21.364220  39.273876
# ...

# %%
# Plot the results.
af.plot_tgp_arc_scenarios('YRI', 'CHA', yri_ooa_cha_winds, yri_ooa_cha_obs, r'$MUC19$', 72)

# %% [markdown]
# ## ((YRI, OOA), Vindija Nean.)

# %%
# Intialize sample configuration lists.
p1s = ['YRI']
p2s = [
    'PEL', 'MXL', 'CLM', 'PUR', # AMR.
    'BEB', 'STU', 'ITU', 'PJL', 'GIH', # SAS.
    'CHB', 'KHV', 'CHS', 'JPT', 'CDX', # EAS.    
    'TSI', 'CEU', 'IBS', 'GBR', 'FIN', # EUR.
]
p3s = ['VIN']
# Load the windowed results.
yri_ooa_vin_winds = af.build_tgp_arc_scenario_window_dicc('tgp', p1s, p2s, p3s, 72)
# Calculate the observed results.
yri_ooa_vin_obs = af.calculate_tgp_arc_scenarios(tgp_72kb_gt, yri_ooa_vin_winds, p1s, p2s, p3s, 72)

# %%
# Compile the results summary.
af.build_tgp_arc_scenario_tables(yri_ooa_vin_obs, yri_ooa_vin_winds, p1s, p2s, p3s, 72)
# Out:
#      P1   P2   P3       ABBA       BABA       BAAA       ABAA       BBAA  \
# 0   YRI  PEL  VIN  17.070602  12.206359  28.422318  27.120711  31.908701
# 1   YRI  MXL  VIN  22.041540  14.996691  31.908402  30.139884  28.422616
# 2   YRI  CLM  VIN   7.764184   9.478477  21.984067  24.647730  38.346951
# 3   YRI  PUR  VIN   8.907096   9.309963  22.762487  23.260795  37.568532
# 4   YRI  BEB  VIN  12.515517  11.084585  24.942466  25.030052  35.388552
# 5   YRI  STU  VIN  10.375658   9.842298  23.720656  23.504834  36.610362
# 6   YRI  ITU  VIN   9.971303   9.842354  23.265353  23.615707  37.065666
# 7   YRI  PJL  VIN   6.676963   8.361280  20.895110  21.832321  39.435909
# 8   YRI  GIH  VIN   9.282621   9.440365  22.926521  23.202299  37.404497
# 9   YRI  CHB  VIN   6.978807   6.041891  20.802050  21.075400  39.528969
# 10  YRI  KHV  VIN   9.940049   7.817784  22.954920  22.560770  37.376099
# 11  YRI  CHS  VIN   7.159877   6.455578  21.064484  21.314418  39.266534
# ...

# %%
# Plot the results.
af.plot_tgp_arc_scenarios('YRI', 'VIN', yri_ooa_vin_winds, yri_ooa_vin_obs, r'$MUC19$', 72)

# %% [markdown]
# ## ((Altai Nean., Young Neanderthals), Denisovan)

# %%
# Intialize sample configuration list.
config_list = [
    ('ALT', 'CHA', 'DEN'),
    ('ALT', 'VIN', 'DEN'),
]
# Load the windowed results.
alt_nea_den_winds = af.build_arc_anc_scenario_window_dicc('arc', config_list, 72)
# Calculate the observed results.
alt_nea_den_obs = af.calculate_arc_anc_scenarios(arc_72kb_gt, config_list, alt_nea_den_winds, 72)

# %%
# Compile the results summary.
af.build_arc_anc_scenario_tables(alt_nea_den_obs, alt_nea_den_winds, config_list, 72)
# Out:
#     P1   P2   P3   ABBA  BABA   BAAA   ABAA   BBAA   AABA      $D+$  \
# 0  ALT  CHA  DEN  40.25   0.0  44.00  11.25  44.50  65.75  0.764398
# 1  ALT  VIN  DEN  41.50   0.0  43.75   9.75  44.75  65.50  0.794737
#
#    Nonoverlapping Windows $\left( \mu \right)$  \
# 0                                    -0.101623
# 1                                    -0.156996
#
#    Nonoverlapping Windows $\left( \sigma \right)$  $P-value$
# 0                                        0.371365   0.019778
# 1                                        0.352960   0.012173

# %%
# Plot the results.
af.plot_arc_anc_scenarios(['DEN', 'DEN'], alt_nea_den_winds, alt_nea_den_obs, r'$MUC19$', 72)

# %% [markdown]
# ## ((Chagyrskaya Nean., Vindija Nean.), Denisovan/Altai Nean.)

# %%
# Intialize sample configuration list.
config_list = [
    ('CHA', 'VIN', 'DEN'),
    ('CHA', 'VIN', 'ALT'),
]
# Load the windowed results.
cha_vin_arc_winds = af.build_arc_anc_scenario_window_dicc('arc', config_list, 72)
# Calculate the observed results.
cha_vin_arc_obs = af.calculate_arc_anc_scenarios(arc_72kb_gt, config_list, cha_vin_arc_winds, 72)

# %%
# Compile the results summary.
af.build_arc_anc_scenario_tables(cha_vin_arc_obs, cha_vin_arc_winds, config_list, 72)
# Out:
#     P1   P2   P3   ABBA   BABA   BAAA   ABAA   BBAA   AABA      $D+$  \
# 0  CHA  VIN  DEN  20.00  19.75  25.50  25.25  28.75  44.25  0.005525
# 1  CHA  VIN  ALT  19.75  19.50  25.75  26.00  24.25  23.75  0.000000
#
#    Nonoverlapping Windows $\left( \mu \right)$  \
# 0                                    -0.088931
# 1                                    -0.088592
#
#    Nonoverlapping Windows $\left( \sigma \right)$  $P-value$
# 0                                        0.376055   0.494139
# 1                                        0.461062   0.500000

# %%
# Plot the results.
af.plot_arc_anc_scenarios(['DEN', 'ALT'], cha_vin_arc_winds, cha_vin_arc_obs, r'$MUC19$', 72)
