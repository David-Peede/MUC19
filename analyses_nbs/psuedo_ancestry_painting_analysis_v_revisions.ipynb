# %% [markdown]
# # Pseudo-Ancestry Painting

# %%
# Import packages.
import analysis_functions as af

# %% [markdown]
# ## 72kb

# %%
# Intialize the genotype matricies.
arcs_no_aa_72kb_gt, _ = af.load_hap_region('arcs_masked_no_aa', 12, 40759001, 40831000)
tgp_arcs_no_aa_72kb_gt, _ = af.load_hap_region('tgp_arcs_masked_no_aa', 12, 40759001, 40831000)

# %%
# Load the observed values.
pap_72kb_obs, pap_plot_72kb = af.calc_pap_scores(arcs_no_aa_72kb_gt, tgp_arcs_no_aa_72kb_gt)
# Load the windowed values.
pap_72kb_winds = af.load_pap_scores_windows(72)
# Compile the summary.
pap_72kb_summary = af.compile_pap_score_summary(pap_72kb_obs, pap_72kb_winds, 72)

# %%
# Show the pap summary.
pap_72kb_summary
# Out:
#     $Source^{1}$           $Target$   $Source^{2}$  \
# 0      Denisovan  Chagyrskaya Nean.    Altai Nean.
# 1      Denisovan      Vindija Nean.    Altai Nean.
# 2  MXL (NA19664)  Chagyrskaya Nean.  YRI (NA19190)
# 3  MXL (NA19664)      Vindija Nean.  YRI (NA19190)
# 4  MXL (NA19664)          Denisovan  YRI (NA19190)
# 5  MXL (NA19664)        Altai Nean.  YRI (NA19190)
#
#    Focal 72kb Region $\left( PAP \text{ Score} \right)$  \
# 0                                           0.791667
# 1                                           0.801170
# 2                                           0.940120
# 3                                           0.929412
# 4                                           0.000000
# 5                                           0.000000
#
#    72kb Non-overlapping Windows $\left( \mu \right)$  \
# 0                                           0.104511
# 1                                           0.084911
# 2                                           0.007686
# ...

# %% [markdown]
# ## Plots

# %%
# Plot the pap score disrtibution.
af.plot_pap_score_dist(pap_72kb_obs, pap_72kb_winds, 72)
