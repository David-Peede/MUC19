# %% [markdown]
# # Heterozygosity

# %%
# Import packages.
import analysis_functions as af
import pandas as pd
# Print version numbers.
print('pandas', pd.__version__)
# Out:
# pandas 1.4.2

# %%
# Intialize the pandas preferences.
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Heterozygosity Amongst the Archaics

# %%
# Load the genotype matrix.
arc_72kb_gt, _ = af.load_hap_region('arc_anc', 12, 40758000, 40830000)

# %%
# Compile the heterozygosity results.
af.compile_arc_het_summary(arc_72kb_gt, 72)
# Out:
#              Archaic  $MUC19$ (Heterozygous Sites)  \
# 0          Denisovan                            12
# 1        Altai Nean.                             1
# 2  Chagyrskaya Nean.                           182
# 3      Vindija Nean.                           181
#
#    Nonoverlapping Windows $\left( \mu \right)$  \
# 0                                    10.208711
# 1                                     9.513633
# 2                                     7.528497
# 3                                     8.836917
#
#    Nonoverlapping Windows $\left( \sigma \right)$               $P-value$
# 0                                       15.152515       0.279339378238342
# 1                                       16.254567      0.7987694300518134
# 2                                       14.340833   0.0002266839378238342
# 3                                       14.413469  0.00038860103626943003

# %%
# Plot the distribution of heterozygous sites.
af.plot_arc_het(arc_72kb_gt, r'$MUC19$', 72)

# %% [markdown]
# ## Heterozygosity Amongst African and Introgressed Individuals

# %%
# Load the genotype matrix.
tgp_72kb_gt, _ = af.load_hap_region('tgp_mod_arc_anc', 12, 40758000, 40830000)

# %%
# Compile the average number of heterozygous sites results.
af.compile_afr_hap_het_summary(tgp_72kb_gt, 72)
# Out:
#                 Group  $MUC19$ (Average Number of Heterozygous Sites)  \
# 0       African Inds.                                       50.158730
# 1  Heterozygous Inds.                                      218.494118
# 2    Homozygous Inds.                                        2.625000
#
#    Nonoverlapping Windows $\left( \mu \right)$  \
# 0                                    50.451627
# 1                                    37.695106
# 2                                    36.258297
#
#    Nonoverlapping Windows $\left( \sigma \right)$               $P-value$
# 0                                       19.886952      0.4548578467922326
# 1                                       17.465937  3.2418063344895776e-05
# 2                                       18.491356    0.001167050280416248

# %%
# Plot the average number of heterozygous sites results.
af.plot_afr_hap_het(tgp_72kb_gt, r'$MUC19$', 72)
